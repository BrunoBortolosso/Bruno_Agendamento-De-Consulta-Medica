# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**
#
# **Turma:**
#
# **Tema Escolhido:**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
class Consulta:
    def __init__(self, paciente, medico, data):
        self.paciente = paciente
        self.medico = medico
        self.data = data

    def exibir_detalhes(self):
        print(f"Paciente: {self.paciente}")
        print(f"Médico: {self.medico}")
        print(f"Data da Consulta: {self.data}")
        
consulta1 = Consulta("Ana Souza", "Dr. João Silva", "2025-06-01")
consulta2 = Consulta("Carlos Lima", "Dra. Maria Fernanda", "2025-06-05")
consulta1.exibir_detalhes()
print("---")
consulta2.exibir_detalhes()


saida esperada no terminal 
Paciente: Ana Souza
Médico: Dr. João Silva
Data da Consulta: 2025-06-01
---
Paciente: Carlos Lima
Médico: Dra. Maria Fernanda
Data da Consulta: 2025-06-05
# Out:
# oi

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
class Consulta:
    def __init__(self, paciente, medico, data):
        self.paciente = paciente
        self.medico = medico
        self.data = data
        self.status = "Agendada"

    def confirmar(self):
        self.status = "Confirmada"
        print(f"Consulta de {self.paciente} confirmada.")

    def cancelar(self):
        self.status = "Cancelada"
        print(f"Consulta de {self.paciente} cancelada.")

    def exibir_detalhes(self):
        print(f"Paciente: {self.paciente}")
        print(f"Médico: {self.medico}")
        print(f"Data: {self.data}")
        print(f"Status: {self.status}")
class ConsultaOnline(Consulta):
    def __init__(self, paciente, medico, data, link_reuniao):
        super().__init__(paciente, medico, data)
        self.link_reuniao = link_reuniao

    def enviar_link(self):
        print(f"Link da consulta enviado para {self.paciente}: {self.link_reuniao}")
consulta1 = Consulta("Ana Souza", "Dr. João Silva", "2025-06-01")
consulta1.confirmar()
consulta1.exibir_detalhes()
print("\n---\n")

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
class Consulta:
    def __init__(self, paciente, medico, data):
        self.paciente = paciente
        self.medico = medico
        self.data = data
        self.__status = "Agendada"  # atributo privado

    # Getter
    def get_status(self):
        return self.__status

    # Setter
    def set_status(self, novo_status):
        if novo_status in ["Agendada", "Confirmada", "Cancelada"]:
            self.__status = novo_status
        else:
            print("Status inválido.")

    # Método com lógica interna (abstração)
    def verificar_urgencia(self):
        data_atual = datetime.now().date()
        data_consulta = datetime.strptime(self.data, "%Y-%m-%d").date()
        dias_restantes = (data_consulta - data_atual).days
        if dias_restantes <= 1:
            return "Urgente"
        else:
            return "Normal"

    def exibir_detalhes(self):
        print(f"Paciente: {self.paciente}")
        print(f"Médico: {self.medico}")
        print(f"Data: {self.data}")
        print(f"Status: {self.__status}")
        print(f"Nível de urgência: {self.verificar_urgencia()}")
consulta = Consulta("João Costa", "Dr. Ricardo Alves", "2025-05-24")  # digite uma data perto da data atual
consulta.set_status("Confirmada")
consulta.exibir_detalhes()

# Tentando setar um status inválido
consulta.set_status("Concluída")  # Deve mostrar erro

 Saída esperada:
makefile
Copiar
Editar
Paciente: João Costa
Médico: Dr. Ricardo Alves
Data: 2025-05-24
Status: Confirmada
Nível de urgência: Urgente

Status inválido.

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
class Consulta:
    def __init__(self, paciente, medico, data):
        self.paciente = paciente
        self.medico = medico
        self.data = data
        self.__status = "Agendada"  # atributo privado

    # Mostra o status (getter)
    def get_status(self):
        return self.__status

    # Muda o status (setter)
    def set_status(self, novo_status):
        if novo_status in ["Agendada", "Confirmada", "Cancelada"]:
            self.__status = novo_status
        else:
            print("Status inválido.")

    # Verifica se a consulta está próxima (urgente)
    def verificar_urgencia(self):
        from datetime import datetime
        hoje = datetime.now().date()
        data_consulta = datetime.strptime(self.data, "%Y-%m-%d").date()
        dias = (data_consulta - hoje).days
        if dias <= 1:
            return "Urgente"
        else:
            return "Normal"

    # Mostra os dados da consulta
    def exibir_detalhes(self):
        print(f"Paciente: {self.paciente}")
        print(f"Médico: {self.medico}")
        print(f"Data: {self.data}")
        print(f"Status: {self.__status}")
        print(f"Urgência: {self.verificar_urgencia()}")
class ConsultaOnline(Consulta):
    def __init__(self, paciente, medico, data, link):
        super().__init__(paciente, medico, data)  # chama a classe mãe
        self.link = link

    # Mostra os dados + link da consulta online
    def exibir_detalhes(self):
        super().exibir_detalhes()
        print(f"Link da consulta: {self.link}")

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# Importando bibliotecas
import sqlite3
from datetime import datetime



class Consulta:
    def __init__(self, paciente, medico, data):
        # Atributos principais
        self.paciente = paciente
        self.medico = medico
        self.data = data
        self.__status = "Agendada"  # Atributo privado (encapsulamento)

    # Getter: mostra o status
    def get_status(self):
        return self.__status

    # Setter: muda o status
    def set_status(self, novo_status):
        if novo_status in ["Agendada", "Confirmada", "Cancelada"]:
            self.__status = novo_status
        else:
            print("Status inválido.")

    # Método que verifica se a consulta está próxima (abstração)
    def verificar_urgencia(self):
        hoje = datetime.now().date()
        data_consulta = datetime.strptime(self.data, "%Y-%m-%d").date()
        dias = (data_consulta - hoje).days
        if dias <= 1:
            return "Urgente"
        else:
            return "Normal"

    # Mostra os dados da consulta
    def exibir_detalhes(self):
        print(f"Paciente: {self.paciente}")
        print(f"Médico: {self.medico}")
        print(f"Data: {self.data}")
        print(f"Status: {self.__status}")
        print(f"Urgência: {self.verificar_urgencia()}")



class ConsultaOnline(Consulta):
    def __init__(self, paciente, medico, data, link):
        super().__init__(paciente, medico, data)  # Usa o construtor da classe mãe
        self.link = link

    # Polimorfismo: sobrescrevendo o método exibir_detalhes
    def exibir_detalhes(self):
        super().exibir_detalhes()
        print(f"Link da consulta: {self.link}")



# Cria a tabela no banco se não existir
def criar_tabela():
    conexao = sqlite3.connect("consultas.db")
    cursor = conexao.cursor()
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS consultas (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            paciente TEXT,
            medico TEXT,
            data TEXT,
            status TEXT
        )
    """)
    conexao.commit()
    conexao.close()

# Insere uma nova consulta no banco
def salvar_consulta(consulta):
    conexao = sqlite3.connect("consultas.db")
    cursor = conexao.cursor()
    cursor.execute("INSERT INTO consultas (paciente, medico, data, status) VALUES (?, ?, ?, ?)",
                   (consulta.paciente, consulta.medico, consulta.data, consulta.get_status()))
    conexao.commit()
    conexao.close()

# Lista todas as consultas do banco
def mostrar_consultas():
    conexao = sqlite3.connect("consultas.db")
    cursor = conexao.cursor()
    cursor.execute("SELECT * FROM consultas")
    dados = cursor.fetchall()
    for linha in dados:
        print(f"ID: {linha[0]} | Paciente: {linha[1]} | Médico: {linha[2]} | Data: {linha[3]} | Status: {linha[4]}")
    conexao.close()

# Deleta uma consulta pelo ID
def deletar_consulta(id_consulta):
    conexao = sqlite3.connect("consultas.db")
    cursor = conexao.cursor()
    cursor.execute("DELETE FROM consultas WHERE id = ?", (id_consulta,))
    conexao.commit()
    conexao.close()



# 1. Criar a tabela no banco
criar_tabela()

# 2. Criar uma consulta normal
consulta1 = Consulta("Ana Silva", "Dr. João", "2025-05-24")
consulta1.set_status("Confirmada")
consulta1.exibir_detalhes()
salvar_consulta(consulta1)

print("\n--------------------\n")

# 3. Criar uma consulta online
consulta2 = ConsultaOnline("Lucas Lima", "Dra. Maria", "2025-05-25", "https://zoom.com/consulta123")
consulta2.set_status("Agendada")
consulta2.exibir_detalhes()
salvar_consulta(consulta2)

print("\n--------------------\n")

# 4. Mostrar todas as consultas salvas
print("Consultas no banco de dados:")
mostrar_consultas()

print("\n--------------------\n")

# 5. Deletar a consulta com ID 1 (teste)
print("Removendo consulta com ID 1...")
deletar_consulta(1)
print("Consultas atualizadas:")
mostrar_consultas()
